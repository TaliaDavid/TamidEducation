# %%
import csv

# %%
import pandas as pd

# %%
import json

# %%
df = pd.read_csv("directory.csv")

# %%
df.dropna()
# Out:
#            Brand  Store Number                           Store Name  \
# 0      Starbucks  47370-257954                        Meritxell, 96
# 11     Starbucks   1579-122101  HCT Abu Dhabi Women's College Block
# 12     Starbucks  32595-122105          Standard Chartered Building
# 20     Starbucks  32767-131566                      Shangri-La Souq
# 45     Starbucks  32640-131563                       Tawam Hospital
# ...          ...           ...                                  ...
# 25594  Starbucks  27082-246744                                Emart
# 25595  Starbucks  21401-212072                                  Rex
# 25596  Starbucks  24010-226985                             Panorama
# 25597  Starbucks  47608-253804                        Rosebank Mall
# 25599  Starbucks  47609-253286                       Mall of Africa
#
#       Ownership Type                                     Street Address  \
# 0           Licensed                                  Av. Meritxell, 96
# ...

# %%
df2 = df.loc[df["State/Province"].str.contains("NY")]

# %%
df3 = df2[["Brand","State/Province","City","Phone Number"]]

# %%
df3
# Out:
#            Brand State/Province              City    Phone Number
# 20858  Starbucks             NY            Albany  (518) 435-9280
# 20859  Starbucks             NY            Albany    518-218-1520
# 20860  Starbucks             NY            Albany    518-489-1112
# 20861  Starbucks             NY            Albany    518-463-6990
# 20862  Starbucks             NY            Albany    518-485-3946
# ...          ...            ...               ...             ...
# 21498    Teavana             NY           Yonkers    914-963-8670
# 21499  Starbucks             NY           Yonkers      3479312521
# 21500  Starbucks             NY           Yonkers    914-237-3681
# 21501  Starbucks             NY           Yonkers    914-337-0139
# 21502  Starbucks             NY  Yorktown Heights    914-243-5997
#
# [645 rows x 4 columns]

# %%
df3.corr()
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
df4 = df2[["Longitude","Latitude"]]

# %%
df4
# Out:
#        Longitude  Latitude
# 20858     -73.82     42.71
# 20859     -73.85     42.69
# 20860     -73.82     42.71
# 20861     -73.75     42.65
# 20862     -73.79     42.66
# ...          ...       ...
# 21498     -73.86     40.96
# 21499     -73.85     40.93
# 21500     -73.84     40.93
# 21501     -73.83     40.98
# 21502     -73.78     41.27
#
# [645 rows x 2 columns]

# %%
df4.corr()
# Out:
#            Longitude  Latitude
# Longitude   1.000000 -0.686177
# Latitude   -0.686177  1.000000
