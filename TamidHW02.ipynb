# %%
import csv

# %%
import pandas as pd

# %%
import json

# %%
df = pd.read_csv("Fish.csv")

# %%
df2 = df[["Species","Weight","Width","Height"]]

# %%
df2
# Out:
#     Species  Weight   Width   Height
# 0     Bream   242.0  4.0200  11.5200
# 1     Bream   290.0  4.3056  12.4800
# 2     Bream   340.0  4.6961  12.3778
# 3     Bream   363.0  4.4555  12.7300
# 4     Bream   430.0  5.1340  12.4440
# ..      ...     ...     ...      ...
# 154   Smelt    12.2  1.3936   2.0904
# 155   Smelt    13.4  1.2690   2.4300
# 156   Smelt    12.2  1.2558   2.2770
# 157   Smelt    19.7  2.0672   2.8728
# 158   Smelt    19.9  1.8792   2.9322
#
# [159 rows x 4 columns]

# %%
byregion = pd.crosstab(df["Length2"],df["Weight"])

# %%
byregion
# Out:
# Weight   0.0     5.9     6.7     7.0     7.5     8.7     9.7     9.8     \
# Length2
# 8.4           0       1       0       0       0       0       0       0
# 9.8           0       0       1       0       0       0       0       0
# 10.5          0       0       0       0       1       0       0       0
# 10.6          0       0       0       1       0       0       0       0
# 11.0          0       0       0       0       0       0       1       0
# ...         ...     ...     ...     ...     ...     ...     ...     ...
# 48.0          0       0       0       0       0       0       0       0
# 51.7          0       0       0       0       0       0       0       0
# 56.0          0       0       0       0       0       0       0       0
# 60.0          0       0       0       0       0       0       0       0
# 63.4          0       0       0       0       0       0       0       0
#
# Weight   9.9     10.0    ...  950.0   955.0   975.0   1000.0  1015.0  1100.0  \
# ...

# %%
df.boxplot(column = ["Weight","Length2"])
# Out:
# <AxesSubplot:>

# %%
df.describe()
# Out:
#             Weight     Length1     Length2     Length3      Height       Width
# count   159.000000  159.000000  159.000000  159.000000  159.000000  159.000000
# mean    398.326415   26.247170   28.415723   31.227044    8.970994    4.417486
# std     357.978317    9.996441   10.716328   11.610246    4.286208    1.685804
# min       0.000000    7.500000    8.400000    8.800000    1.728400    1.047600
# 25%     120.000000   19.050000   21.000000   23.150000    5.944800    3.385650
# 50%     273.000000   25.200000   27.300000   29.400000    7.786000    4.248500
# 75%     650.000000   32.700000   35.500000   39.650000   12.365900    5.584500
# max    1650.000000   59.000000   63.400000   68.000000   18.957000    8.142000

# %%
max_df = df["Weight"].max()

# %%
max_df
# Out:
# 1650.0

# %%
df.loc[df["Species"].str.contains("Pike")]
# Out:
#     Species  Weight  Length1  Length2  Length3   Height   Width
# 128    Pike   200.0     30.0     32.3     34.8   5.5680  3.3756
# 129    Pike   300.0     31.7     34.0     37.8   5.7078  4.1580
# 130    Pike   300.0     32.7     35.0     38.8   5.9364  4.3844
# 131    Pike   300.0     34.8     37.3     39.8   6.2884  4.0198
# 132    Pike   430.0     35.5     38.0     40.5   7.2900  4.5765
# 133    Pike   345.0     36.0     38.5     41.0   6.3960  3.9770
# 134    Pike   456.0     40.0     42.5     45.5   7.2800  4.3225
# 135    Pike   510.0     40.0     42.5     45.5   6.8250  4.4590
# 136    Pike   540.0     40.1     43.0     45.8   7.7860  5.1296
# 137    Pike   500.0     42.0     45.0     48.0   6.9600  4.8960
# 138    Pike   567.0     43.2     46.0     48.7   7.7920  4.8700
# 139    Pike   770.0     44.8     48.0     51.2   7.6800  5.3760
# 140    Pike   950.0     48.3     51.7     55.1   8.9262  6.1712
# 141    Pike  1250.0     52.0     56.0     59.7  10.6863  6.9849
# ...
